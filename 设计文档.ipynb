# %% [markdown]
# 1、验证连接google drive，读取事先上传到google drive的数据

# %%
# %tensorflow_version 1.x

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# TensorFlow 1.x selected.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# 2、定位到执行代码文件夹目录下。

# %%
import os

path = "/content/drive/My Drive/bert-master"
os.chdir(path)
os.listdir(path)
# Out:
# ['predicting_movie_reviews_with_bert_on_tf_hub.ipynb',
#  'requirements.txt',
#  'run_pretraining.py',
#  'run_squad.py',
#  'optimization.py',
#  '.gitignore',
#  'extract_features.py',
#  'tokenization_test.py',
#  'sample_text.txt',
#  '__init__.py',
#  'multilingual.md',
#  'create_pretraining_data.py',
#  'README.md',
#  'modeling.py',
#  'LICENSE',
#  'run_classifier_with_tfhub.py',
#  'optimization_test.py',
#  'modeling_test.py',
#  'tokenization.py',
#  'CONTRIBUTING.md',
#  'download_glue_data.py',
#  'SST.zip',
#  'run_classifier.py',
#  'output',
#  'glue_dir',
#  '__pycache__']

# %% [markdown]
# 3、设置参数并执行bert模型的python文件。
#   其中这里直接读取由google-research分享的中文版bert预训练模型。
#   设置max_seq_length =128
#     train_batch_size = 32
#     learning_rate = 2e-5
#     num_train_epochs = 5.0。
#   运行文件后将生成的测试集分类结果文件test_result_tsv保存在output/game_output文件夹下。
#   具体bert模型可以参照https://github.com/google-research/bert/blob/master/README.md 这里改动了数据读取模块，改动代码在代码文件夹中。

# %%
# !python run_classifier.py \
				  --task_name=game \
  --do_train=true \
  --do_eval=false \
  --do_predict=true \
  --data_dir=glue_dir/game/ \
  --vocab_file=../chinese_L-12_H-768_A-12/vocab.txt \
  --bert_config_file=../chinese_L-12_H-768_A-12/bert_config.json \
  --init_checkpoint=../chinese_L-12_H-768_A-12/bert_model.ckpt \
  --max_seq_length=128 \
  --train_batch_size=32 \
  --learning_rate=2e-5 \
  --num_train_epochs=5.0 \
  --output_dir=output/game_output/
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# I0507 05:30:31.302184 140202102314880 tpu_estimator.py:2308] examples/sec: 109.566
# INFO:tensorflow:global_step/sec: 3.61864
# I0507 05:30:31.578164 140202102314880 tpu_estimator.py:2307] global_step/sec: 3.61864
# INFO:tensorflow:examples/sec: 115.796
# I0507 05:30:31.578545 140202102314880 tpu_estimator.py:2308] examples/sec: 115.796
# INFO:tensorflow:global_step/sec: 3.73563
# I0507 05:30:31.845869 140202102314880 tpu_estimator.py:2307] global_step/sec: 3.73563
# INFO:tensorflow:examples/sec: 119.54
# I0507 05:30:31.846187 140202102314880 tpu_estimator.py:2308] examples/sec: 119.54
# INFO:tensorflow:global_step/sec: 3.46111
# I0507 05:30:32.134765 140202102314880 tpu_estimator.py:2307] global_step/sec: 3.46111
# INFO:tensorflow:examples/sec: 110.756
# I0507 05:30:32.135135 140202102314880 tpu_estimator.py:2308] examples/sec: 110.756
# INFO:tensorflow:global_step/sec: 3.69177
# ...

# %% [markdown]
# 4、将生成的tsv文件转化为题目要求的txt文件。

# %%
import os

path = "/content/drive/My Drive/bert-master/output/game_output"
os.chdir(path)
os.listdir(path)
# !python tsv2txt.py
